# %% [markdown]
# # Data Visualization Gallery
#
# Images of all current data visualizations I have created. The below script scans all folders to print out all saved images.

# %% [markdown]
# ## Import Packages

# %%
import os

from IPython.display import Image

# %% [markdown]
# ## Create a function and set paths
# Function display images when a path and filename is set.

# %%
## Create a function to display images
def slide(img):
    display( Image(img, height = 200) )
    
    
## set cwd
path = os.getcwd() 


## image folder name
imageFolder="\\images"

folders = os.listdir()
folders.remove('.ipynb_checkpoints')

# %% [markdown]
# ## Print Images
# The function below loops through all folders in data projects. Searches each folder for an images folder. If an images folder exists and at least one file is available, print the file(s).

# %%
for i in folders:
    ## Set the path to the CWD, add a variable, then search for the images folder
    check=path + "\\" + i + "\\" + imageFolder + "\\"
    ## Loop through all folders in data projects
    if os.path.isdir(check):
        ## Check to see if files exist
        listFiles = os.listdir(check)
        ## If files exist, use user function to dispaly all files
        for f in listFiles:
            if '.ipynb_checkpoints' not in f:
                print(f)
# Out:
# ibm_2004_stock_by_month.jpeg
# Countries_under_target.jpeg
# cars.jpeg
# clientspanel.jpeg
# clientspanel_color.jpeg
# clients_dual_bar.jpeg
# clients_line.jpeg
# covidscamsMap_final.jpeg
# covidscamsMap_firstattempt.jpeg
# covidscamsMap_second.jpeg
# Overall.jpeg
# ReasonSerentiva.jpeg
# CumulativeSteps.jpeg
# OverallStandings.jpeg
# StepBreakdown.jpeg
# StepsByWeek.jpeg
# WeekendWarriorByPerson.jpeg
# WinnerByCompetition.jpeg
# WorkweekHustleByPerson.jpeg
# kitchen_remodel_quotes1.jpeg
# wcTax.jpg
# AirOverMeanbar.jpeg
# AirOverMeanSeries.jpeg

# %%
for i in folders:
    ## Set the path to the CWD, add a variable, then search for the images folder
    check=path + "\\" + i + "\\" + imageFolder + "\\"
    ## Loop through all folders in data projects
    if os.path.isdir(check):
        ## Check to see if files exist
        listFiles = os.listdir(check)
        ## If files exist, use user function to dispaly all files
        for f in listFiles:
            if '.ipynb_checkpoints' not in f:
                print(f)
                slide(check + f)
# Out:
# ibm_2004_stock_by_month.jpeg
# Countries_under_target.jpeg
# cars.jpeg
# clientspanel.jpeg
# clientspanel_color.jpeg
# clients_dual_bar.jpeg
# clients_line.jpeg
# covidscamsMap_final.jpeg
# covidscamsMap_firstattempt.jpeg
# covidscamsMap_second.jpeg
# Overall.jpeg
# ReasonSerentiva.jpeg
# CumulativeSteps.jpeg
# OverallStandings.jpeg
# StepBreakdown.jpeg
# StepsByWeek.jpeg
# WeekendWarriorByPerson.jpeg
# WinnerByCompetition.jpeg
# WorkweekHustleByPerson.jpeg
# kitchen_remodel_quotes1.jpeg
# wcTax.jpg
# AirOverMeanbar.jpeg
# AirOverMeanSeries.jpeg
