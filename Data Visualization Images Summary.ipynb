# %%
from IPython.display import Image
def slide(img):
    display( Image(img + ".jpeg", retina=True) )

# %%
slide(r'C:\Users\pestyl\OneDrive - SAS\github repos\Data Projects\Kitchen Remodel Quotes\kitchen_remodel_quotes')

# %%
slide(r'C:\Users\pestyl\OneDrive - SAS\github repos\Data Projects\2004 IBM Stock Price\ibm_2004_stock_by_month')
