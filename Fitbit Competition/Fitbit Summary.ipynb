# %%
from IPython.display import Image
import os

path=os.getcwd() +'\\images'

def imgDisplay(img,w):
    display(Image(path +"\\" +img + ".jpeg",width=w))

# %%
path
# Out:
# 'C:\\Users\\pestyl\\OneDrive - SAS\\github repos\\Data Projects\\Fitbit Competition\\images'

# %%
imgDisplay("OverallStandings",700)

# %%
imgDisplay("WinnerByCompetition",2000)

# %%
imgDisplay("CumulativeSteps",1000)

# %%
imgDisplay("StepsByWeek",1000)

# %%
imgDisplay("WorkweekHustleByPerson",1000)

# %%
imgDisplay("WeekendWarriorByPerson",1000)

# %%
imgDisplay("StepBreakdown",1000)
