# %%
import pandas as pd

# %%
df = pd.read_csv('HPI Data.csv')

# %%
df.head()
# Out:
#   State   County  FIPS code  Year Annual Change (%)     HPI  \
# 0    AL  Autauga       1001  1986                 .     100
# 1    AL  Autauga       1001  1987             -2.31   97.69
# 2    AL  Autauga       1001  1988              3.36  100.97
# 3    AL  Autauga       1001  1989              4.26  105.27
# 4    AL  Autauga       1001  1990              -0.4  104.86
#
#   HPI with 1990 base HPI with 2000 base
# 0              95.37              70.91
# 1              93.16              69.27
# 2              96.29               71.6
# 3              100.4              74.65
# 4                100              74.35

# %%
df = df[(df['State']=='NC') & (df['Year']>=1990)]

# %%
df
# Out:
#       State    County  FIPS code  Year Annual Change (%)     HPI  \
# 51906    NC  Alamance      37001  1990              2.46  246.62
# 51907    NC  Alamance      37001  1991              2.46   252.7
# 51908    NC  Alamance      37001  1992              1.62   256.8
# 51909    NC  Alamance      37001  1993               1.5  260.65
# 51910    NC  Alamance      37001  1994              3.67  270.21
# ...     ...       ...        ...   ...               ...     ...
# 55065    NC    Yancey      37199  2014              2.45  162.88
# 55066    NC    Yancey      37199  2015             -0.39  162.24
# 55067    NC    Yancey      37199  2016              1.68  164.97
# 55068    NC    Yancey      37199  2017              9.71  180.99
# 55069    NC    Yancey      37199  2018              0.98  182.76
#
#       HPI with 1990 base HPI with 2000 base
# 51906                100              71.14
# 51907             102.46              72.89
# 51908             104.13              74.08
# ...

# %%
df.drop('FIPS code',axis=1, inplace=True)

# %%
df
# Out:
#       State    County  Year Annual Change (%)     HPI HPI with 1990 base  \
# 51906    NC  Alamance  1990              2.46  246.62                100
# 51907    NC  Alamance  1991              2.46   252.7             102.46
# 51908    NC  Alamance  1992              1.62   256.8             104.13
# 51909    NC  Alamance  1993               1.5  260.65             105.69
# 51910    NC  Alamance  1994              3.67  270.21             109.56
# ...     ...       ...   ...               ...     ...                ...
# 55065    NC    Yancey  2014              2.45  162.88                  .
# 55066    NC    Yancey  2015             -0.39  162.24                  .
# 55067    NC    Yancey  2016              1.68  164.97                  .
# 55068    NC    Yancey  2017              9.71  180.99                  .
# 55069    NC    Yancey  2018              0.98  182.76                  .
#
#       HPI with 2000 base
# 51906              71.14
# 51907              72.89
# ...

# %%
df.to_csv('HPI_NC.csv', index=False)

# %%
df.Year.value_counts()
# Out:
# 2017    99
# 2015    99
# 2002    99
# 2004    99
# 2006    99
# 2008    99
# 2010    99
# 2012    99
# 2014    99
# 2016    99
# 2018    99
# 2009    99
# 2003    99
# 2005    99
# 2007    99
# 2011    99
# 2013    99
# 2001    98
# 2000    97
# 1999    96
# 1998    94
# 1997    87
# 1996    85
# 1995    83
# 1994    79
# 1993    78
# 1992    73
# 1991    60
# 1990    58
# Name: Year, dtype: int64

# %%
df[df['County']=='Wake']
# Out:
#       State County  Year Annual Change (%)     HPI HPI with 1990 base  \
# 54795    NC   Wake  1990              1.48  254.21                100
# 54796    NC   Wake  1991              1.11  257.03             101.11
# 54797    NC   Wake  1992               1.8  261.65             102.92
# 54798    NC   Wake  1993              2.48  268.14             105.48
# 54799    NC   Wake  1994              6.96  286.81             112.82
# 54800    NC   Wake  1995              7.01  306.93             120.74
# 54801    NC   Wake  1996              3.32   317.1             124.74
# 54802    NC   Wake  1997              3.97  329.68             129.69
# 54803    NC   Wake  1998              3.13  339.99             133.74
# 54804    NC   Wake  1999              3.59  352.19             138.54
# 54805    NC   Wake  2000              4.36  367.56             144.59
# 54806    NC   Wake  2001              3.45  380.26             149.58
# ...
